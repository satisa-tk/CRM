# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/HW_CRM
# Out:
# /content/drive/My Drive/HW_CRM

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from mlxtend) (57.2.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.4.1)
# Requirement already satisfied: pandas>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (1.1.5)
# Requirement already satisfied: matplotlib>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from mlxtend) (3.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.5.1->mlxtend) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.5.1->mlxtend) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.5.1->mlxtend) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.5.1->mlxtend) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.5.1->mlxtend) (1.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=1.5.1->mlxtend) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.1->mlxtend) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->mlxtend) (1.0.1)

# %%
# !pip install -U --pre matplotlib  
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('/content/drive/My Drive/HW_CRM/font/K2D-Light.ttf')
mpl.rc('font', family='K2D')
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (3.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.19.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from scipy.spatial.distance import cosine

# %%
df = pd.read_csv("Customer Preference Survey.csv")
df.head()
# Out:
#                              ประทับเวลา  ... ครีมกันแดด
# 0  2564/03/20 11:29:58 ก่อนเที่ยง GMT+7  ...        NaN
# 1  2564/03/20 11:33:10 ก่อนเที่ยง GMT+7  ...        NaN
# 2  2564/03/20 11:53:44 ก่อนเที่ยง GMT+7  ...        เคย
# 3  2564/03/20 11:54:00 ก่อนเที่ยง GMT+7  ...        เคย
# 4  2564/03/20 11:54:05 ก่อนเที่ยง GMT+7  ...        เคย
#
# [5 rows x 62 columns]

# %%
df = df.iloc[2:,1:].reset_index(drop=True).copy()
df.head()
# Out:
#   จักรยานเสือภูเขา คอลลาเจน  ... Software ถูกลิขสิทธิ์ ครีมกันแดด
# 0           ไม่เคย   ไม่เคย  ...                   เคย        เคย
# 1           ไม่เคย      เคย  ...                ไม่เคย        เคย
# 2              เคย   ไม่เคย  ...                   เคย        เคย
# 3           ไม่เคย   ไม่เคย  ...                ไม่เคย        เคย
# 4           ไม่เคย      เคย  ...                   เคย        เคย
#
# [5 rows x 61 columns]

# %%
df.melt()['value'].value_counts(dropna=False)
# Out:
# ไม่เคย    1710
# เคย       1090
# NaN          6
# Name: value, dtype: int64

# %%
df = df.dropna()
df.melt()['value'].value_counts(dropna=False)
# Out:
# ไม่เคย    1518
# เคย        983
# Name: value, dtype: int64

# %%
df.replace({'เคย': 1, 'ไม่เคย': 0}, inplace=True)
df.head()
# Out:
#    จักรยานเสือภูเขา  คอลลาเจน  ...  Software ถูกลิขสิทธิ์  ครีมกันแดด
# 0                 0         0  ...                      1           1
# 1                 0         1  ...                      0           1
# 2                 1         0  ...                      1           1
# 3                 0         0  ...                      0           1
# 6                 0         0  ...                      1           1
#
# [5 rows x 61 columns]

# %%
df[['เครื่องย่อยเศษอาหาร', 'เครื่องย่อยเศษอาหาร.1']].corr()
# Out:
#                        เครื่องย่อยเศษอาหาร  เครื่องย่อยเศษอาหาร.1
# เครื่องย่อยเศษอาหาร                    1.0                    1.0
# เครื่องย่อยเศษอาหาร.1                  1.0                    1.0

# %%
df.drop('เครื่องย่อยเศษอาหาร.1',axis=1, inplace=True)
df.describe().T.sort_values('mean', ascending=False)
# Out:
#                                  count      mean       std  ...  50%  75%  max
# ครีมกันแดด                        41.0  1.000000  0.000000  ...  1.0  1.0  1.0
# กระเป๋า                           41.0  1.000000  0.000000  ...  1.0  1.0  1.0
# ชาบู                              41.0  1.000000  0.000000  ...  1.0  1.0  1.0
# โรตี                              41.0  0.975610  0.156174  ...  1.0  1.0  1.0
# กะหรี่(ปั๊บ)                      41.0  0.951220  0.218085  ...  1.0  1.0  1.0
# เม็ดมะม่วงหิมพานต์                41.0  0.902439  0.300406  ...  1.0  1.0  1.0
# หมอนข้าง                          41.0  0.878049  0.331295  ...  1.0  1.0  1.0
# Software ถูกลิขสิทธิ์             41.0  0.804878  0.401218  ...  1.0  1.0  1.0
# หมูแดดเดียว                       41.0  0.804878  0.401218  ...  1.0  1.0  1.0
# แฟน ที่แปลว่าพัดลม                41.0  0.804878  0.401218  ...  1.0  1.0  1.0
# เนื้อย่าง                         41.0  0.731707  0.448575  ...  1.0  1.0  1.0
# น้ำส้มดีโด้                       41.0  0.707317  0.460646  ...  1.0  1.0  1.0
# เนื้อวากิล                        41.0  0.682927  0.471117  ...  1.0  1.0  1.0
# ต้นไม้ประดับห้อง                  41.0  0.682927  0.471117  ...  1.0  1.0  1.0
# Board game                        41.0  0.658537  0.480091  ...  1.0  1.0  1.0
# Lego                              41.0  0.658537  0.480091  ...  1.0  1.0  1.0
# ตาชั่ง                            41.0  0.658537  0.480091  ...  1.0  1.0  1.0
# ที่ยกน้ำหนัก (Dumbell)            41.0  0.609756  0.493865  ...  1.0  1.0  1.0
# คอลลาเจน                          41.0  0.560976  0.502433  ...  1.0  1.0  1.0
# เครื่องดูดฝุ่นอัตโนมัติ (robot)   41.0  0.536585  0.504854  ...  1.0  1.0  1.0
# แพ็คเกจไทยเที่ยวไทย               41.0  0.487805  0.506061  ...  0.0  1.0  1.0
# มะม่วงเบา                         41.0  0.414634  0.498779  ...  0.0  1.0  1.0
# กรรไกรตัดขนจมูก                   41.0  0.390244  0.493865  ...  0.0  1.0  1.0
# เครื่องวัดความดัน                 41.0  0.390244  0.493865  ...  0.0  1.0  1.0
# หมอนสุขภาพสำหรับคนนอนไม่หลับ      41.0  0.390244  0.493865  ...  0.0  1.0  1.0
# ชุดน้องหมา                        41.0  0.341463  0.480091  ...  0.0  1.0  1.0
# ไฟอัจฉริยะ                        41.0  0.341463  0.480091  ...  0.0  1.0  1.0
# จักรยานเสือภูเขา                  41.0  0.341463  0.480091  ...  0.0  1.0  1.0
# แสงโสม                            41.0  0.317073  0.471117  ...  0.0  1.0  1.0
# ยาดอง                             41.0  0.292683  0.460646  ...  0.0  1.0  1.0
# แม่โขง                            41.0  0.292683  0.460646  ...  0.0  1.0  1.0
# หลอดไฟเปลี่ยนสีได้                41.0  0.268293  0.448575  ...  0.0  1.0  1.0
# ไพ่ยิปซี                          41.0  0.243902  0.434769  ...  0.0  0.0  1.0
# เสื้อซีทรู                        41.0  0.243902  0.434769  ...  0.0  0.0  1.0
# เครื่องตรวจน้ำตาลในเลือด          41.0  0.243902  0.434769  ...  0.0  0.0  1.0
# Omakase                           41.0  0.219512  0.419058  ...  0.0  0.0  1.0
# กะปิดอง                           41.0  0.219512  0.419058  ...  0.0  0.0  1.0
# น้องหมา                           41.0  0.195122  0.401218  ...  0.0  0.0  1.0
# ถั่งเช่า                          41.0  0.195122  0.401218  ...  0.0  0.0  1.0
# บัตตาเลี่ยนที่ตัดผม               41.0  0.195122  0.401218  ...  0.0  0.0  1.0
# แผ่นเสียง                         41.0  0.195122  0.401218  ...  0.0  0.0  1.0
# ชุดนอนไม่ได้นอน                   41.0  0.170732  0.380949  ...  0.0  0.0  1.0
# Botox                             41.0  0.170732  0.380949  ...  0.0  0.0  1.0
# เครื่องทำลายเอกสาร                41.0  0.170732  0.380949  ...  0.0  0.0  1.0
# drone                             41.0  0.146341  0.357839  ...  0.0  0.0  1.0
# เกมส์ FIFA Online                 41.0  0.146341  0.357839  ...  0.0  0.0  1.0
# กัญชา                             41.0  0.146341  0.357839  ...  0.0  0.0  1.0
# เก้าอี้นวดไฟฟ้า                   41.0  0.146341  0.357839  ...  0.0  0.0  1.0
# ข้าวขาหมูคากิคาจักออนไลน์         41.0  0.121951  0.331295  ...  0.0  0.0  1.0
# คอร์ส bikini wax                  41.0  0.097561  0.300406  ...  0.0  0.0  1.0
# ไดร์เป่าผม Dyson                  41.0  0.097561  0.300406  ...  0.0  0.0  1.0
# คอร์สโบท็อกกราม                   41.0  0.097561  0.300406  ...  0.0  0.0  1.0
# อาหารแมวคลีนเพื่อสุขภาพลดหุ่น     41.0  0.097561  0.300406  ...  0.0  0.0  1.0
# Brownie อวกาศ                     41.0  0.097561  0.300406  ...  0.0  0.0  1.0
# กัญชง                             41.0  0.073171  0.263652  ...  0.0  0.0  1.0
# ห้องน้ำแมวอัตโนมัติ               41.0  0.073171  0.263652  ...  0.0  0.0  1.0
# กระเป๋า chanel                    41.0  0.073171  0.263652  ...  0.0  0.0  1.0
# Surfskate                         41.0  0.073171  0.263652  ...  0.0  0.0  1.0
# PS5                               41.0  0.048780  0.218085  ...  0.0  0.0  1.0
# เครื่องย่อยเศษอาหาร               41.0  0.048780  0.218085  ...  0.0  0.0  1.0
#
# [60 rows x 8 columns]

# %%
purchase = (df.sum().sort_values(ascending=False).to_frame().rename({0: 'count'}, axis=1))
most = purchase[:10]
less = purchase[-10:]

fig, axes = plt.subplots(1, 2, figsize=(20, 5), tight_layout=True)
most.sort_values('count', ascending=True).plot.barh(ax=axes[0], title='Most Purchase/Use', legend=False, color='lightblue')
less.plot.barh(ax=axes[1], title='Less Purchase/Use', legend=False, color='lightblue')
plt.rc('axes', titlesize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_len"] = rules["consequents"].apply(lambda x: len(x))
rules.head(10)
# Out:
#                                      antecedents  ... consequents_len
# 19641             (เนื้อวากิล, ต้นไม้ประดับห้อง)  ...               3
# 20089            (หมูแดดเดียว, ต้นไม้ประดับห้อง)  ...               3
# 20391              (เนื้อย่าง, ต้นไม้ประดับห้อง)  ...               3
# 36351                        (หมูแดดเดียว, Lego)  ...               3
# 37783           (แฟน ที่แปลว่าพัดลม, เนื้อวากิล)  ...               3
# 38833            (แฟน ที่แปลว่าพัดลม, เนื้อย่าง)  ...               3
# 55245  (หมูแดดเดียว, หมอนข้าง, ต้นไม้ประดับห้อง)  ...               3
# 55870    (หมอนข้าง, เนื้อย่าง, ต้นไม้ประดับห้อง)  ...               3
# 61758    (กระเป๋า, เนื้อวากิล, ต้นไม้ประดับห้อง)  ...               3
# 61776             (เนื้อวากิล, ต้นไม้ประดับห้อง)  ...               4
#
# [10 rows x 11 columns]

# %%
item = rules[ 
    (rules['antecedent_len'] == 1) &
    (rules['consequents_len'] == 1) &
    (rules['confidence'] >= 0.5) &
    (rules['lift'] >= 1) 
]
item["antecedents"] = item["antecedents"].apply(lambda x: list(x)[0]).astype("unicode")
item["consequents"] = item["consequents"].apply(lambda x: list(x)[0]).astype("unicode")
item = item.sort_values('lift', ascending=False)
item.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           antecedents       consequents  ...  antecedent_len  consequents_len
# 160        เนื้อวากิล         เนื้อย่าง  ...               1                1
# 161         เนื้อย่าง        เนื้อวากิล  ...               1                1
# 16               Lego  ต้นไม้ประดับห้อง  ...               1                1
# 17   ต้นไม้ประดับห้อง              Lego  ...               1                1
# 74         Board game           ตาชั่ง   ...               1                1
# 75            ตาชั่ง         Board game  ...               1                1
# 25   ต้นไม้ประดับห้อง         เนื้อย่าง  ...               1                1
# 24          เนื้อย่าง  ต้นไม้ประดับห้อง  ...               1                1
# 105         เนื้อย่าง              Lego  ...               1                1
# 104              Lego         เนื้อย่าง  ...               1                1
#
# [10 rows x 11 columns]

# %%
G = nx.from_pandas_edgelist(item, source='antecedents', target='consequents', edge_attr='lift')
d = dict(G.degree)
nx.draw_circular(
    G, 
    node_size=[d[k] * 300 for k in dict(G.degree)], 
    with_labels=True, 
    font_family='K2D',
    node_color='lightblue'
) 
plt.rcParams["figure.figsize"] = (10, 10)
plt.show()

# %%
item_item_matrix = pd.DataFrame(index=df.columns,columns=df.columns)

# %%
from scipy.spatial.distance import cosine

for i in range(0,len(item_item_matrix.columns)) :
    for j in range(0,len(item_item_matrix.columns)) :
      item_item_matrix.iloc[i,j] = 1 -cosine(df.iloc[:,i], df.iloc[:,j])

item_item_matrix.head(10)
# Out:
#                    จักรยานเสือภูเขา  คอลลาเจน  ... Software ถูกลิขสิทธิ์ ครีมกันแดด
# จักรยานเสือภูเขา                  1  0.557278  ...              0.604815   0.584349
# คอลลาเจน                   0.557278         1  ...              0.725954   0.748983
# Brownie อวกาศ              0.267261  0.312772  ...              0.348155   0.312348
# แม่โขง                     0.385758  0.361158  ...              0.351763   0.541002
# Botox                      0.404061  0.551677  ...              0.460566   0.413197
# กัญชา                      0.218218  0.170251  ...              0.284268   0.382546
# กัญชง                      0.154303  0.240772  ...              0.301511   0.270501
# เครื่องวัดความดัน          0.467707  0.469157  ...              0.609272   0.624695
# หลอดไฟเปลี่ยนสีได้         0.483494  0.377217  ...               0.57735    0.51797
# คอร์ส bikini wax           0.133631  0.417029  ...              0.261116   0.312348
#
# [10 rows x 60 columns]

# %%
links = item_item_matrix.rename_axis('related item', 
                                     axis='columns').stack().reset_index()
links.columns = ['item', 'related item','value']

# %%
links_filtered=links.loc[ (links['value'] > 0.5) & 
                         (links['item'] != links['related item']) ]

# %%
fig, ax=plt.subplots(figsize=(15,15))
GA=nx.from_pandas_edgelist(links_filtered,source='item',target='related item')
nx.draw(GA,
        with_labels=True,
        font_family='K2D',
        node_color='lightblue')
plt.show()
